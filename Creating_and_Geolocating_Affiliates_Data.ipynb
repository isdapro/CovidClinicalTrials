# %%
#Initially, I will discuss how to get the affiliates data. I observed 5 major data sources: biorxiv, medrxiv, elsevier, pmc and cnz. Pubmed API and Selenium scraping customized 
#for major journals like medr,bior,sciencedirect gives a good fill rate

# %%
# !apt update
# !apt install chromium-chromedriver
# !pip install selenium

# %%
# !pip install ratelimit

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
wd = webdriver.Chrome('chromedriver',options=options)
find_el = wd.find_elements_by_xpath
wd.implicitly_wait(30)
wd.set_page_load_timeout(30)

# %%
#The various scraping functions
def node_text(node):
    if node.text:
        result = node.text
    else:
        result = ''
    for child in node:
        if child.tail is not None:
            result += child.tail
    return result

def scrape_else(data):
  try:
    wd.get("https://doi.org/"+data)
    more_button = find_el("//button[@class='show-hide-details u-font-sans']")[0]
    more_button.click()
    l=[]
    for i in find_el("//dl[@class='affiliation']/dd"):
      l.append(i.text)
    return l
  except:
    l=[]
    return l

@sleep_and_retry
@limits(calls=1, period=1)
def czi_affiliations(data):
  try:
    PMC_ID = data.lstrip('PMC')
    response = requests.get('https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id='+PMC_ID)
    root = ElementTree.fromstring(response.content)
    l=[]
    for i in root.iter('aff'):
      l.append(node_text(i))
    return l
  except:
    l=[]
    return l

def scrape_bior(data):
  try:
    wd.get("https://doi.org/"+data)
    wd.get(wd.current_url+".article-info")
    l=[]
    for i in find_el("//ol[@class='affiliation-list']/li/address/span"):
      l.append(i.text)
    return l
  except:
    l=[]
    return l

#Medr aldo follows bior structure so same function can be used

# %%
#Not putting the scraping results here as they were mult-threaded and run on a different env

# %%
#For websites that redirect to PDFs
import os
d=dict()
c=0
root_dir = '/content/gdrive/My Drive'
for root,dirs, files in os.walk(root_dir):
  for file in files:
    c+=1
    print(c)
    if 'pdf' in file:
      name = file.lstrip('PII').rstrip('.pdf')
      l=[]
      try:
        wd.get("https://www.sciencedirect.com/science/article/pii/"+name)
        t1 = find_el("//a[@class='doi']")[0]
        more_button = find_el("//button[@class='show-hide-details u-font-sans']")[0]
        more_button.click()
        for i in find_el("//dl[@class='affiliation']/dd"):
          l.append(i.text)
        d[t1.text.lstrip('https://doi.org/')]=l
      except:
        pass

# %%
#Here on, we eill discuss the geolocation part
# !sudo apt-get install curl autoconf automake libtool python-dev pkg-config
# !git clone https://github.com/openvenues/libpostal
cd libpostal
# !./bootstrap.sh
# !sudo mkdir /opt/libpostal 
# !./configure --datadir=/opt/libpostal
# !make 
# !sudo make install

# %%
pip install postal
# Out:
# Collecting postal
#   Using cached https://files.pythonhosted.org/packages/56/f7/69ca5d374077e23aa9a51ecd4031222ca9dfb7d19c95d7691f024e2e27ef/postal-1.1.8.tar.gz
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from postal) (1.12.0)
# Building wheels for collected packages: postal
#   Building wheel for postal (setup.py) ... done
#   Created wheel for postal: filename=postal-1.1.8-cp36-cp36m-linux_x86_64.whl size=162432 sha256=a175cfb9fb8d0c610e63d36be7bf63d5528d690587d04a20d98011e0794f0129
#   Stored in directory: /root/.cache/pip/wheels/07/a1/d6/5d48641ee6f7c494c35534661d367b966b2b398e3789f48ffc
# Successfully built postal
# Installing collected packages: postal
# Successfully installed postal-1.1.8

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import pandas as pd
import numpy as np

# %%
#Reading in the COVID affiliates data previously created, https://github.com/isdapro/CovidClinicalTrials/blob/master/Datasets/covid_affiliates.csv
df = pd.read_csv("covid_affiliates.csv")

# %%
from ast import literal_eval
df['affiliate'] = df['affiliate'].apply(literal_eval)

# %%
from geopy.geocoders import Nominatim, GeoNames, DataBC, ArcGIS, TomTom, Bing, GoogleV3
geolocator = Bing(api_key="BING_API_KEY")

# %%
def extract_country(data):
  s = set()
  for el in data:
    d = dict(parse_address(el))
    inv_map = {v: k for k, v in d.items()}
    if 'country' in inv_map.keys():
      s.add(inv_map['country'])
    elif 'city' in inv_map.keys():
      try:
        s.add(geolocator.geocode(inv_map['city']).raw['address']['countryRegion'])
      except:
        pass
    elif 'house' in inv_map.keys():
      try:
        s.add(geolocator.geocode(inv_map['house']).raw['address']['countryRegion'])
      except:
        pass
  return list(s)

# %%
# !pip install pandarallel

# %%
from pandarallel import pandarallel

# %%
pandarallel.initialize()
# Out:
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
from tqdm import tqdm
tqdm.pandas()

# %%
def set_cleaner(data):
  s = set()
  for i in data:
    s.add(i.lower())
  return list(s)

# %%
df['geolocated_country'] = df['affiliate'].parallel_apply(extract_country)
df['geolocated_country'] = df['geolocated_country'].parallel_apply(set_cleaner)

# %%
df.head(50)
# Out:
#     Unnamed: 0  ...                                 geolocated_country
# 0            0  ...                                                 []
# 1            1  ...                                         [colombia]
# 2            2  ...                    [saudi arabia, colombia, nepal]
# 3            3  ...                        [the netherlands, portugal]
# 4            4  ...                                                 []
# 5            5  ...                                                 []
# 6            6  ...                                                 []
# 7            7  ...                                       [china, usa]
# 8            8  ...                                        [australia]
# 9            9  ...                                                 []
# 10          10  ...                                                 []
# 11          11  ...                                                 []
# 12          12  ...                                                 []
# 13          13  ...                                                 []
# 14          14  ...                                                 []
# 15          15  ...                                                 []
# 16          16  ...                                    [united states]
# 17          17  ...                [japan, argentina, colombia, nepal]
# 18          18  ...                                                 []
# 19          19  ...                        [china, colombia, pakistan]
# 20          20  ...                                [saudi arabia, usa]
# 21          21  ...                                            [china]
# 22          22  ...                                                 []
# 23          23  ...                                                 []
# 24          24  ...                                                 []
# 25          25  ...                                                 []
# 26          26  ...                                                 []
# 27          27  ...  [paraguay, venezuela, brazil, mexico, chile, p...
# 28          28  ...                                                 []
# 29          29  ...    [venezuela, saudi arabia, nepal, colombia, usa]
# 30          30  ...                                                 []
# 31          31  ...                               [united states, usa]
# 32          32  ...         [argentina, colombia, brazil, switzerland]
# 33          33  ...                                                 []
# 34          34  ...                                            [china]
# 35          35  ...                                                 []
# 36          36  ...                                                 []
# 37          37  ...                                            [china]
# 38          38  ...                                                 []
# 39          39  ...                                                 []
# 40          40  ...                                                 []
# 41          41  ...                                                 []
# 42          42  ...                                                 []
# 43          43  ...                                                 []
# 44          44  ...                                                 []
# 45          45  ...                                [republic of china]
# 46          46  ...                                                 []
# 47          47  ...                                                 []
# 48          48  ...                                                 []
# 49          49  ...                            [france, taiwan, italy]
#
# [50 rows x 6 columns]

# %%
df.to_csv("geolocated_affiliations.csv")

# %%
linked_trials = pd.read_csv("ClinicalTrialsLinked.csv")

# %%
#Running the geolocation logic on the VT SHA papers
sha_vt = pd.read_csv("sha_vt.csv")
sha_vt.drop_duplicates(subset ="sha", inplace = True)

# %%
len(set(sha_vt.sha))
# Out:
# 253

# %%
metadata = pd.read_csv("metadata.csv")

# %%
#We need the DOI also for getting affiliate data so some merges are necessary
metadata = pd.read_csv("metadata.csv")
metadata = metadata.dropna(subset=['sha'])
s = metadata['sha'].str.split(';').apply(pd.Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = 'sha'
del metadata['sha']
cleaned_meta = metadata.join(s)
merged = sha_vt.merge(cleaned_meta, left_on='sha', right_on='sha')

# %%
#Just avoiding work for papers that we have already extracted the data for
merged2 = merged.merge(df,how='left',left_on='sha',right_on='Id')

# %%
merged_compact = merged2[['sha','doi_x','pmcid','affiliate','geolocated_country']]

# %%
# !pip install ratelimit

# %%
import requests
from tqdm import tqdm
tqdm.pandas()
import xml.etree.ElementTree as ElementTree
from ratelimit import limits, sleep_and_retry
def node_text(node):
    if node.text:
        result = node.text
    else:
        result = ''
    for child in node:
        if child.tail is not None:
            result += child.tail
    return result

@sleep_and_retry
@limits(calls=1, period=1)
def affiliations(data):
  try:
    PMC_ID = data.lstrip('PMC')
    response = requests.get('https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pmc&id='+PMC_ID)
    root = ElementTree.fromstring(response.content)
    l=[]
    for i in root.iter('aff'):
      l.append(node_text(i))
    return l
  except:
    l=[]
    return l

# %%
def fun(data):
  if not isinstance(data.affiliate,list):
    tmp = affiliations(data.pmcid)
    data.affiliate = tmp
  print(data)
  return data

# %%
merged_compact2 = merged_compact.parallel_apply(fun,axis=1)

# %%
#80% fill rate
merged_compact2['geolocated_country'].apply(lambda x: len(x)).value_counts()

# %%
df_final = merged_compact2[['sha','geolocated_country']]

# %%
df_final
# Out:
#                                           sha                                 geolocated_country
# 0    00c71f72eb837e2342dbda8761664e221e2a03df                                                 []
# 1    05192151667b1bb4e3405de11f6e4ae2f844e7c5                                            [china]
# 2    056610b4981cee0efc485ed3f978f541fbe55f54                                               [uk]
# 3    0792384d074cef963c808eacf3c63e3654776a2a                                                 []
# 4    0c36cc3dc9a1632f0fbf14372f376f89521718c5                                          [germany]
# 5    0dca038ac8dfd45a921b7cd9f1c90a8554799e23                                                 []
# 6    0dd1ab1f5811f3a1fe36f45577846243b3cf14f8                                            [china]
# 7    0eadf5a901c0d89fad2c202990056556be103e12                                           [china.]
# 8    0f6a5070fd5f9bd5d46c3bbd4545c55982e726c3                                           [france]
# 9    1007a3041cb5ae9e3e6f09712d81277c02ed3dbf                                                 []
# 10   106db157fd5d6ee766feabadf0d35a24d6d37895                                                 []
# 11   114ed64f52f503d9d2e2ba1fd1ee62b0a168cd84                                 [australia, china]
# 12   16f0732b9fee4779a3eb38280b344f866692d346                                            [china]
# 13   1766a9d5945897581c80f83276cc723c77e3798d                                                 []
# 14   188e7ff1e260864c89f266b5597de26d69a84660                                                 []
# 15   19a08cc1423d6006b2251bdcfd142f88db7002e7                            [turkey, united states]
# 170  ba94dbb19b3a574e0f02dbd34b75c42359a52358    [hong kong special administrative region china]
# 171  baabfb35a321ea12028160e0d2c1552a2fda2dd5                                            [china]
# 172  bcf51d33bc41647bbea9b36ba89ebaae13c4a982                                               [uk]
# 173  bdd38af290f6aa98b23b9278047ca06f232c081a                           [germany, france, spain]
# 174  bdfe90336091a24dd75c44257b4707a4a903d22b                                    [turkey, china]
# 175  c12a11fa9c5fdff0bf85a9f0111c64d6dffe8d26                                                 []
# 176  c12d71462529856463c2432d5628d10a0027c404                                                 []
# 177  c3bf8040e0bb5b6667bf25a4be148aa55b18acf0                                             [iraq]
# 178  c646e655066d0982c151b516ebdf0334d037ffcf                              [egypt, saudi arabia]
# 179  c6ec1380338cb2467dc6fc14add09ca5bea18411                             [china, united states]
# 180  c747c5b5cdebe39ac26640ddfb010724d938d649                                    [united states]
# 181  c954675ee859e2f7b8f352a398a67469b50f05de                                           [turkey]
# 182  ca36180197f0a2bda83c8c743b1cad8d4c90924e                                                 []
# 183  cbf20969da0fdadbb513502aa324d940defc5f15                                                 []
# 184  cd70d9a7adb120c4fcbe4aa8a1bd64a7d8483764                                                 []
# 185  cfeda05ff998d6973560c4f55577a5feaeccb59b                                            [spain]
# 186  d16e1bd4c6cae1bb55dbc695c5e2ba5105a13921                                          [germany]
# 187  d2b1853aae556beaf9e1bc9d802642fffe35cf68                                            [china]
# 188  d33817b56a98cb895588efa155ae076ec74ec139                                    [canada, spain]
# 189  d3744e7581b12fe33a93e21e89b5da988b790b4b                                              [usa]
# 190  d3bf1b40c7c93d6bd6ef2d1769b0e68ed233c18a                                            [italy]
# 191  d4cfb1fc4fc53abbc1d4b0ca60276c6af6632c3c                                    [turkey, china]
# 192  d4f9d334eb5ffbefbef6c90a23f7a243fa89065c                                            [china]
# 193  d6a34d159840a3895ac1768920a1c498d3c448c6            [kingdom of saudi arabia, saudi arabia]
# 194  d9d218af628830db318305235b3b252d85f62dea                                                 []
# 195  db142fe07544dcf0e454f8a9f39452f0aa92a6ca                                           [turkey]
# 196  db9b9f34fb37dfbeef7e0e900e834e982536de56                   [united states, canada, denmark]
# 197  dbefc8ad2a3de5d1696b7e604de8bce1da2ea8cd                              [turkey, south korea]
# 198  dc3656324843f16d93801bac3e78a5fd316ac988                                                 []
# 199  ddc40ffc47069f3714c8da65843f36f41ed0f8bb                             [india, united states]
# 200  dfb0fedbeed56bd2b795a67faab28295afc14c96  [turkey, people's republic of china, china, se...
# 201  e04b5db8306ab29c14bbaa9d1de25e98839ed70c                                                 []
# 202  e08ff7855eaa0c9d0bb785dcffc24e65910b7184                                               [uk]
# 203  e0ec89c24c99c50b1f83ed2d77fe7bd5ef94dc8a                                  [germany, poland]
# 204  e2273d397d1b0c37a010d81be706c2a28af62c9e                                            [italy]
# 205  e3b40cc8e0e137c416b4a2273a4dca94ae8178cc                                            [china]
# 206  e3c87d73a6abced2f827ee3e6daf050663b9b7fb                                              [usa]
# 207  e47779a5dd554c5a35cdb58e5e7fb682ec177f24                                            [china]
# 208  e4b18c2650a0735f7db3a316ff8c560da61931bb                                                 []
# 209  e52ecf4b22e9dcb340ccf67f0251b5a3f9373f02                                                 []
# 210  e5a5a852ae1cdcd98504799f618a8bebbfd7128c                                         [ethiopia]
# 211  e67124fe8f187a99ef873140524fefc50796eccc                                    [united states]
# 212  e6af63ce394cb9c51c04251c99565fd0e6d58c1b                             [china, united states]
# 213  e6d2c030bb4bb71cae43fd29624e70872b1662a4                                                 []
# 214  e6d3acfd725e130a51eab3efafcf05dfb1febbc9          [hong kong special administrative region]
# 215  e7a4159ce5cead74ff87dc1199e3f461631adf96                            [france, canada, italy]
# 216  e847d433e7424152a9846673209cb73027415ecd                                                 []
# 217  e889b19090410704479ea3c7a1596b827f3dbcd0                                           [china.]
# 218  e9895961fa3aee4ebcaa947a2111ec9e64cbbfbf                                     [india, china]
# 219  e9dfbc4084497e74dcaf6bd9c1dbde2b0fb70802                                                 []
# 220  ea646b114ea01f978d205ed97405e1f2afed2dfd                                                 []
# 221  eb5bfeea7bc4bb15dcf2ad3e26dc6478c277fd6e                                          [finland]
# 222  eba1da4b90ee7cff2811391e12e773baa5cd6c2e                                          [germany]
# 223  ebfc471829e1303889bd23779d1c2ffb9467ab7e                                                 []
# 224  ed344fa4250b398132e3066793aadfa9a305cf78                                                 []
# 225  ed99ea6c7af5c77db2bf336d263db55646686098                                                 []
# 226  eff6ce20122149117020cda90ad17f7cff0e9fd4                                    [united states]
# 227  f0a7684b84d874e9d61eee9c4cff37bb45bb2547                                      [south korea]
# 228  f0d2dc18c4737a62d2de12b56d4dba143d21344a                                                 []
# 229  f0dea096a4f73085b277b6977c8c3367b2957a6e                                    [hong kong sar]
# 230  f10fb0ee869f01e39652ca0079888562e865b0ea                   [germany, united states, france]
# 231  f14434d7d3b68f4fe7f68adba747b7700ccdd6ac                             [hong kong sar, china]
# 232  f279037d5e828d9b0b9f6f262c0386925a70f846                                            [china]
# 233  f5cce8a5be5bc7be7a749a51ce8f71add6e5d08f                                                 []
# 234  f6b9fd7dbed6516888eca71004caaa62aa0132d4                                            [china]
# 235  f7f99b10a8f56b2e0e85885a30ef3e3f3258ce7d                                                 []
# 236  f8c15039fad3e71a1479b9d09516aad16fc52f70                                            [china]
# 237  fa0c32f39abb602e0161bf738b5292e251c0c885                            [united states, canada]
# 238  faa2aa0782a6ca9f4072e4918205358347219799                                    [united states]
# 239  faf3ed3d6fc359c1f310e32061e5ed414fee7017                                                 []
# 240  fb0c496af128204a417aa9b18ce6ed674cbbff6e                                                 []
# 241  fbe041fcdd278e6044874daa9f9e071b95b4d2ef                                                 []
# 242  fc766f4da6dcc43946f06f65cde8d79dcb740c11                           [saudi arabia, ethiopia]
# 243  fd28e6d03eef27b0454f13ca539dc1498242a4c2                                    [china, canada]
# 244  fd6af3846d9cfd5b1c9f86b5e16ec803a88cc1f5                                                 []
# 245  ff1cc08ebe7f5a104152662fa87ff683524165c7                                                 []

# %%
df_final.to_csv("drug_geolocated.csv")
